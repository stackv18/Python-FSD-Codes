# %%
def div(a,b):
    try:
        print(a/b)
    except exeption as e:
        print(e)
        
    else:
        print("na hoy")#try thay to aa pan print thay
    finally:
        print("aa to thai ne j reh")
div(5,0)
# Out:
# aa to thai ne j reh
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-219e9ea3472d> in div(a, b)
#       2     try:
# ----> 3         print(a/b)
#       4     except exeption as e:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-219e9ea3472d> in <module>
#       9     finally:
#      10         print("aa to thai ne j reh")
# ---> 11 div(5,0)
#
# <ipython-input-1-219e9ea3472d> in div(a, b)
#       2     try:
#       3         print(a/b)
# ----> 4     except exeption as e:
#       5         print(e)
#       6
#
# NameError: name 'exeption' is not defined

# %%
f=open("cf.txt",'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2eaf27c9d29b> in <module>
# ----> 1 f=open("cf.txt",'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cf.txt'

# %%
x=7
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-07a65d58c006> in <module>
#       1 x=7
# ----> 2 print(y)
#
# NameError: name 'y' is not defined

# %%
print(div(5,0))
# Out:
# aa to thai ne j reh
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-219e9ea3472d> in div(a, b)
#       2     try:
# ----> 3         print(a/b)
#       4     except exeption as e:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-922b0e494095> in <module>
# ----> 1 print(div(5,0))
#
# <ipython-input-1-219e9ea3472d> in div(a, b)
#       2     try:
#       3         print(a/b)
# ----> 4     except exeption as e:
#       5         print(e)
#       6
#
# NameError: name 'exeption' is not defined

# %%
try:
    f=open("ddfd.txt",'r')
except FileNotFoundError:
       print(".")
# Out:
# .

# %%
try:
    m=5
    f=open("xyz.txt")
    print(f.read())
    print(n)
    print(5/0)
    l=(1,2,3)
    l[1]
except FileNotFoundError:
    print(".")
except ZeroDivisionError:
    print("/")
except NameError:
    print(",")
except Exception as e:
    print("//")
# Out:
# welcome to ljiet
# this is python lecture
# ,

# %%
def add(a,b):
    if type(a)==str:
        raise Mahi("a na chale")
    if type(b)==str:
        raise Mahi("b pan na chale")
    else:
        print(a+b)
add("10",20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ce3f83ea89cd> in <module>
#       6     else:
#       7         print(a+b)
# ----> 8 add("10",20)
#
# <ipython-input-2-ce3f83ea89cd> in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise Mahi("a na chale")
#       4     if type(b)==str:
#       5         raise Mahi("b pan na chale")
#
# NameError: name 'Mahi' is not defined

# %%
class Mahi(Exception):
    def __init__(self,msg):
        self.msg=msg
def add(a,b):
    if type(a)==str:
        raise Mahi("a na chale")
    if type(b)==str:
        raise Mahi("b pan na chale")
    else:
        print(a+b)
add("10",20)
# Out:
# ---------------------------------------------------------------------------
# Mahi                                      Traceback (most recent call last)
# <ipython-input-5-dc7582d845d1> in <module>
#       9     else:
#      10         print(a+b)
# ---> 11 add("10",20)
#
# <ipython-input-5-dc7582d845d1> in add(a, b)
#       4 def add(a,b):
#       5     if type(a)==str:
# ----> 6         raise Mahi("a na chale")
#       7     if type(b)==str:
#       8         raise Mahi("b pan na chale")
#
# Mahi: a na chale

# %%
class low_balance(Exception):
        def __init__(self,msg):
             self.msg=msg
                

amount=12000
a=int(input("enter amount to withdraw:"))
if a<amount or a==amount:
         a=amount-a
         print(a)
if a>amount:
     raise low_balance("amount is out of range")
# Out:
# enter amount to withdraw:20000
# ---------------------------------------------------------------------------
# low_balance                               Traceback (most recent call last)
# <ipython-input-6-0325a885451b> in <module>
#      10          print(a)
#      11 if a>amount:
# ---> 12      raise low_balance("amount is out of range")
#      13
#      14
#
# low_balance: amount is out of range

# %% [markdown]
# ## Intro to oop:

# %%
x=42
print(type(x))
# Out:
# <class 'int'>

# %%
a="ramesh"
print(type(a))
# Out:
# <class 'str'>

# %%
import math
print(type(math.pi))
# Out:
# <class 'float'>

# %%
class Example():
    pass
obj1=Example()
obj2=Example()
print(id(obj1))
print(id(obj2))
# Out:
# 2591970313648
# 2591970313792

# %%
class Employee():
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
keval=Employee(keval.name,keval.age)
hiren=Employee(hiren.name,hiren.age)
keval.name="manish"
keval.age=29
hiren.name='100000'
hiren.age=19
print(keval.name)
print(hiren.age)
# Out:
# manish
# 19

# %%
class Employee():
    def __init__(self):
        print(id(self))
keval=Employee()
print(id(keval))
# Out:
# 2591970312496
# 2591970312496

# %%
class Employee():
    def __init__(self,name,age,salary):
        self.name=name
        self.age=age
        self.salary=salary
        self.increment=0.5
        
    def emp(self):
        self.salary=self.salary*self.increment
        print(f"salary is {self.salary}")
keval=Employee(29,"manish",12000)
keval.emp()
# Out:
# salary is 6000.0

# %% [markdown]
# 1.parameterised constructor
# 2.non-parameterised constructor
# 3.default constructor

# %%
class check:
    fav="apple"
    def __init__(self):
        self.fav="orange"
        self.show()
    def show(self):
        print(self.fav)
s=check()
# Out:
# orange

# %%
class check:
    fav="apple"
    def __init__(self):
       # self.fav="orange"
        self.show()
    def show(self):
        print(self.fav)
s=check()
# Out:
# apple

# %%
class Employee():
    def __init__(self,name,age,salary):
        self.name=name
        self.age=age
        self.salary=salary
        self.increment=0.5
        
    def emp(self):
        self.salary=self.salary*self.increment
        print(f"salary is {self.salary}")
keval=Employee(29,"manish",12000)
hiren=Employee(29,"manish",12000)
keval.emp()
hiren.emp()
del hiren
hiren.emp()
# Out:
# salary is 6000.0
# salary is 6000.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-4312f317a0ee> in <module>
#      14 hiren.emp()
#      15 del hiren
# ---> 16 hiren.emp()
#
# NameError: name 'hiren' is not defined

# %%
def fun():
    yield 12
    yield 14
x=fun()
print(x)
# Out:
# <generator object fun at 0x0000025B7EF08BA0>

# %%
def fun():
    yield 12
    yield 14
x=fun()
for i in x:
    print(i)
# Out:
# 12
# 14

# %%
def fun():
    yield 10,20,30
x=fun()
print(x)
for i in x:
    print(i)
# Out:
# <generator object fun at 0x0000028D491E2BA0>
# (10, 20, 30)

# %%
def fun():
    return 10,20,30
x=fun()
print(x)
for i in x:
    print(i)
# Out:
# (10, 20, 30)
# 10
# 20
# 30

# %%
def multiple_yields():
    s1="ramesh"
    yield s1
    s2="suresh"
    yield s2
    s3="mahesh"
    yield s3
x=multiple_yields()
print(next(x))
print(next(x))
print(next(x))
print(next(x))
# Out:
# ramesh
# suresh
# mahesh
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-6-d34ebae5be6e> in <module>
#      10 print(next(x))
#      11 print(next(x))
# ---> 12 print(next(x))
#
# StopIteration:

# %%
class Student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
tej=Student('tejas',10)
print(tej.name)
print(tejas.name)
print(self.name)
# Out:
# tejas
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a60e9c047c26> in <module>
#       5 tej=Student('tejas',10)
#       6 print(tej.name)
# ----> 7 print(tejas.name)
#       8 print(self.name)
#
# NameError: name 'tejas' is not defined

# %%
class Student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
    def show(self):
        print(self.name)
tej=Student('tejas',10)
tej.show()
print(tej.name)
# Out:
# tejas
# tejas

# %%
class Student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
    @staticmethod
    def show():
        print("hello, how are you?")
tej=Student('tejas',10)
tej.show()
print(tej.name)
# Out:
# hello, how are you?
# tejas

# %%
class fun():
    def __init__(self,name):
        self.name=name
x=fun("dfdjffdsnjd")
print(x.name)
# Out:
# dfdjffdsnjd

# %%
class fun():
    def __init__(self):
        print("constructor created")
    def __del__(self):
        print("constructor destroyed")
x=fun()
del x
# Out:
# constructor created
# constructor destroyed
# constructor destroyed

# %%
class calc:
    a=30
    b=40
    @classmethod
    def addition(cls,a,b):
        print(cls.a)
        print(cls.b)
calc.addition(10,20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-185e74ac7144> in <module>
#       6         print(cls.a)
#       7         print(cls.b)
# ----> 8 calc.addition(a,b)
#
# NameError: name 'a' is not defined

# %%
class myclass:
    a=5
    def __init__(self,x):
        self.x=x
    def func(self):
        print(self.x)
    @classmethod
    def method(cls):
        print(cls.x)
    @staticmethod
    def method1(y):
        print(y)

myclass.x
x=myclass(9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-02adf87f68cb> in <module>
#      12         print(y)
#      13
# ---> 14 myclass.x
#      15 x=myclass(9)
#
# AttributeError: type object 'myclass' has no attribute 'x'

# %%
class student:
    schoolname="LJIET"
    def __init__(self,name,age):
        self.name=name
        self.age=age
s=student("ramesh",12)
print(s.name)
print(s.age)
# Out:
# ramesh
# 12
# LJIET
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2012e4c0a617> in <module>
#       8 print(s.age)
#       9 print(student.schoolname)
# ---> 10 print(name)
#
# NameError: name 'name' is not defined

# %%
class student:
    schoolname="LJIET"
    def __init__(self,name,age):
        self_name=name
        self_age=age
s=student("ramesh",12)
print(s.name)
print(s.age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1c0c2ff860f0> in <module>
#       5         self_age=age
#       6 s=student("ramesh",12)
# ----> 7 print(s.name)
#       8 print(s.age)
#
# AttributeError: 'student' object has no attribute 'name'

# %%
class student:
    schoolname="LJIET"
    def __init__(self,name,age):
        self.name=name
        self.age=age
s=student("ramesh",32)
print(s.name)
print(s.age)
# Out:
# ramesh
# 32

# %%
class student:
    schoolname="LJIET"
    def __init__(self,name,age):
        self.__name=name
        self.__age=age
s=student("ramesh",32)
print(s.__name)
print(s.__age)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-730d23c87348> in <module>
#       5         self.__age=age
#       6 s=student("ramesh",32)
# ----> 7 print(s.__name)
#       8 print(s.__age)
#
# AttributeError: 'student' object has no attribute '__name'
